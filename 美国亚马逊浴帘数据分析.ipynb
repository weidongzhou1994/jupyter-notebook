# %% [markdown]
# &emsp;&emsp;这是一份从美国亚马逊网站上爬取的浴帘数据。

# %% [markdown]
# # 数据处理

# %% [markdown]
# &emsp;&emsp;导入数据：

# %%
import pandas as pd
import numpy as np
from pyecharts.charts import Bar, Line, Grid, Pie, HeatMap
from pyecharts import options as opts
from pyecharts.globals import ThemeType
import matplotlib.pyplot as plt

df = pd.read_excel('./美国浴帘2021.1.20.xlsx')

# %% [markdown]
# &emsp;&emsp;查看数据的基本信息：

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   编号      49 non-null     int64
#  1   商品链接    49 non-null     object
#  2   标题      49 non-null     object
#  3   商标      49 non-null     object
#  4   Asin    49 non-null     object
#  5   销量      47 non-null     float64
#  6   价格      49 non-null     object
#  7   上架时间    49 non-null     datetime64[ns]
#  8   评分      49 non-null     float64
#  9   评价数量    49 non-null     int64
#  10  评级      49 non-null     int64
#  11  评分.1    49 non-null     int64
#  12  材料      49 non-null     object
# dtypes: datetime64[ns](1), float64(2), int64(4), object(6)
# memory usage: 5.1+ KB

# %% [markdown]
# &emsp;&emsp;可以看到：销量只有47个非空值，其他变量均有49个非空值，表明销量数据存在空值，需要剔除。

# %%
data = df.dropna()

# %% [markdown]
# &emsp;&emsp;数据类型也需要进行相应的转换：价格变量的类型需要转换为 float。

# %%
# 价格变量中有 None 值，直接转换会出错
data.loc[:,'价格'] = data.loc[:,'价格'].replace('None', 0).astype('float64')

# %% [markdown]
# &emsp;&emsp;进一步筛选价格不等于 0 的数据：

# %%
data = data[data['价格'] != 0]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46 entries, 0 to 48
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   编号      46 non-null     int64
#  1   商品链接    46 non-null     object
#  2   标题      46 non-null     object
#  3   商标      46 non-null     object
#  4   Asin    46 non-null     object
#  5   销量      46 non-null     float64
#  6   价格      46 non-null     float64
#  7   上架时间    46 non-null     datetime64[ns]
#  8   评分      46 non-null     float64
#  9   评价数量    46 non-null     int64
#  10  评级      46 non-null     int64
#  11  评分.1    46 non-null     int64
#  12  材料      46 non-null     object
# dtypes: datetime64[ns](1), float64(3), int64(4), object(5)
# memory usage: 5.0+ KB

# %% [markdown]
# &emsp;&emsp;再来看一下，数据的各个变量都代表什么内容：
#
# - 编号：无效信息，由爬虫人员生成，无实际意义；
# - 商品链接：无效信息，表示商品的亚马逊链接，可用于核查数据是否准确；
# - 标题：由商标等信息组成，可能从中拆分出有用的信息，需要进一步分析；
# - 商标：表示商品的品牌名；
# - [Asin](https://zhuanlan.zhihu.com/p/214132694)：无效信息，由亚马逊根据 UPC 代码自动生成的唯一商品标识代码；
# - 销量：有效信息，表示商品的销售数量；
# - 价格：有效信息，表示商品的销售价格；
# - 上架时间：有效信息，可结合其他信息，比如销售数量，计算日销量等。
# - 评分：有效信息，表示买家对商品的喜爱度；
# - 评价数量：有效信息，评价数量小于销售数量，可用于计算评价率等指标；
# - 评级：目前并不清楚它代表的信息，需要结合业务进行了解；
# - 评分.1：目前并不清楚它代表的信息，需要结合业务进行了解；
# - 材料：有效信息，表示商品的制造材料。

# %% [markdown]
# &emsp;&emsp;接下来可以简单看一下数据的分布情况：

# %%
data.describe()
# Out:
#               编号            销量         价格        评分          评价数量  \
# count  46.000000     46.000000  46.000000  46.00000     46.000000
# mean   25.413043   3807.391304  19.935870   4.61087   3086.239130
# std    14.966000   6335.532522   6.323935   0.16361   6526.992413
# min     1.000000    570.000000   8.280000   4.10000     37.000000
# 25%    12.250000   1335.000000  14.990000   4.50000    934.000000
# 50%    25.500000   1635.000000  19.990000   4.60000   1881.000000
# 75%    37.750000   3502.500000  23.865000   4.70000   2913.750000
# max    50.000000  38910.000000  39.990000   4.80000  44610.000000
#
#                 评级        评分.1
# count    46.000000   46.000000
# mean    414.260870   74.565217
# std     624.473376  130.761131
# min       0.000000    0.000000
# 25%      38.500000    4.000000
# 50%      93.500000   15.500000
# 75%     423.750000   55.250000
# max    2341.000000  471.000000

# %% [markdown]
# &emsp;&emsp;可以看出：销量、价格、评分的分布比较合理，极值对平均值的影响不大，评级数量则不同，极值的存在影响了平均值。

# %% [markdown]
# # 销售量与销售额

# %% [markdown]
# &emsp;&emsp;先计算销售额：$销售额=销量 \times 价格$

# %%
data['销售额'] = data['销量']*data['价格']

# %% [markdown]
# &emsp;&emsp;再利用数据透视表计算各品牌的销量和销售额：

# %%
sale_data = data.pivot_table(index='商标',
                           values=['销量', '销售额', '评分'],
                           aggfunc={
                               '销量': 'sum',
                               '销售额': 'sum',
                               '评分': 'mean'
                           }).round(1)

# %% [markdown]
# &emsp;&emsp;再计算累计销量占比和累计销售额占比：

# %%
sale_cum_data = sale_data.sort_values('销量', ascending=False).apply(lambda x: x.cumsum()/x.sum()).round(2)

# %% [markdown]
# &emsp;&emsp;进行可视化展示：

# %%
bar = (Bar()
       .add_xaxis(sale_data.sort_values('销量', ascending=False).index.tolist())
       .add_yaxis(
            "销量", 
            sale_data.sort_values('销量', ascending=False)['销量'].tolist(),
           yaxis_index=0
       )
       .extend_axis(yaxis=opts.AxisOpts(position="right"))
       .set_global_opts(
           title_opts=opts.TitleOpts(
               title="各品牌浴帘的销量", 
               pos_left="left"
           ),
           xaxis_opts=opts.AxisOpts(
               axistick_opts=opts.AxisTickOpts(is_align_with_label=True),
               axislabel_opts=opts.LabelOpts(rotate=-90)
           )
       )
       .set_series_opts(label_opts=opts.LabelOpts(is_show=False, position='left'))
       )

line = (
    Line()
    .add_xaxis(sale_data.sort_values('销量', ascending=False).index.tolist())
    .add_yaxis(
        "累计销量占比",
        sale_cum_data['销量'].tolist(),
        yaxis_index=1,
        label_opts=opts.LabelOpts(is_show=False, position='left'),
    )
)

bar.overlap(line)
grid = Grid(init_opts=opts.InitOpts(theme=ThemeType.VINTAGE))
grid.add(bar, opts.GridOpts(pos_left="10%", pos_right="10%", pos_bottom="25%"), is_control_axis_index=True)
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="ba077b03278b4be59a767c725fc01c73" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_ba077b03278b4be59a767c725fc01c73 = echarts.init(
#                     document.getElementById('ba077b03278b4be59a767c725fc01c73'), 'vintage', {renderer: 'canvas'});
#                 var option_ba077b03278b4be59a767c725fc01c73 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u9500\u91cf",
#             "yAxisIndex": 0,
#             "data": [
#                 48300.0,
#                 22909.0,
#                 20345.0,
#                 10501.0,
#                 10212.0,
#                 8340.0,
#                 8310.0,
#                 7050.0,
#                 4170.0,
#                 4140.0,
#                 3972.0,
#                 3300.0,
#                 3090.0,
#                 2951.0,
#                 2670.0,
#                 1920.0,
#                 1620.0,
#                 1560.0,
#                 1410.0,
#                 1380.0,
#                 1260.0,
#                 1110.0,
#                 990.0,
#                 990.0,
#                 960.0,
#                 870.0,
#                 810.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "left",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u7d2f\u8ba1\u9500\u91cf\u5360\u6bd4",
#             "connectNulls": false,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "AmazerBath",
#                     0.28
#                 ],
#                 [
#                     "mDesign",
#                     0.41
#                 ],
#                 [
#                     "Stall",
#                     0.52
#                 ],
#                 [
#                     "Amazon Basics",
#                     0.58
#                 ],
#                 [
#                     "Madison Park",
#                     0.64
#                 ],
#                 [
#                     "Lush Decor",
#                     0.69
#                 ],
#                 [
#                     "YoKII",
#                     0.74
#                 ],
#                 [
#                     "Barossa Design",
#                     0.78
#                 ],
#                 [
#                     "N&Y HOME",
#                     0.8
#                 ],
#                 [
#                     "ARICHOMY",
#                     0.82
#                 ],
#                 [
#                     "Biscaynebay",
#                     0.85
#                 ],
#                 [
#                     "Volens",
#                     0.87
#                 ],
#                 [
#                     "Kikcoin",
#                     0.88
#                 ],
#                 [
#                     "Mrs Awesome",
#                     0.9
#                 ],
#                 [
#                     "Reisen",
#                     0.92
#                 ],
#                 [
#                     "Comfort Spaces",
#                     0.93
#                 ],
#                 [
#                     "Felisa",
#                     0.94
#                 ],
#                 [
#                     "UFRIDAY",
#                     0.94
#                 ],
#                 [
#                     "DOSLY ID\u00c9ES",
#                     0.95
#                 ],
#                 [
#                     "Italian Collection",
#                     0.96
#                 ],
#                 [
#                     "CAROMIO",
#                     0.97
#                 ],
#                 [
#                     "Carnation",
#                     0.97
#                 ],
#                 [
#                     "WestWeir",
#                     0.98
#                 ],
#                 [
#                     "Eforcurtain",
#                     0.98
#                 ],
#                 [
#                     "HALL & PERRY",
#                     0.99
#                 ],
#                 [
#                     "YOSTEV",
#                     1.0
#                 ],
#                 [
#                     "Central Park",
#                     1.0
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "left",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9500\u91cf",
#                 "\u7d2f\u8ba1\u9500\u91cf\u5360\u6bd4"
#             ],
#             "selected": {
#                 "\u9500\u91cf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": true,
#                 "inside": false
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -90,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "AmazerBath",
#                 "mDesign",
#                 "Stall",
#                 "Amazon Basics",
#                 "Madison Park",
#                 "Lush Decor",
#                 "YoKII",
#                 "Barossa Design",
#                 "N&Y HOME",
#                 "ARICHOMY",
#                 "Biscaynebay",
#                 "Volens",
#                 "Kikcoin",
#                 "Mrs Awesome",
#                 "Reisen",
#                 "Comfort Spaces",
#                 "Felisa",
#                 "UFRIDAY",
#                 "DOSLY ID\u00c9ES",
#                 "Italian Collection",
#                 "CAROMIO",
#                 "Carnation",
#                 "WestWeir",
#                 "Eforcurtain",
#                 "HALL & PERRY",
#                 "YOSTEV",
#                 "Central Park"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,

# %% [markdown]
# &emsp;&emsp;可以看出：
# 1. AmazerrBath 品牌的浴帘销量最高且明显高于其他品牌;
# 2. 从累计销量占比来看，前三个品牌的浴帘销量占比超过50%。

# %%
bar = (Bar()
       .add_xaxis(sale_data.sort_values('销售额', ascending=False).index.tolist())
       .add_yaxis(
            "销售额", 
            sale_data.sort_values('销售额', ascending=False)['销售额'].tolist(),
           yaxis_index=0
       )
       .extend_axis(yaxis=opts.AxisOpts(position="right"))
       .set_global_opts(
           title_opts=opts.TitleOpts(
               title="各品牌浴帘的销售额", 
               pos_left="left"
           ),
           xaxis_opts=opts.AxisOpts(
               axistick_opts=opts.AxisTickOpts(is_align_with_label=True),
           axislabel_opts=opts.LabelOpts(rotate=-90)
           )
       )
       .set_series_opts(label_opts=opts.LabelOpts(is_show=False, position='left'))
       )

line = (
    Line()
    .add_xaxis(sale_data.sort_values('销售额', ascending=False).index.tolist())
    .add_yaxis(
        "累计销售额占比",
        sale_cum_data['销售额'].tolist(),
        yaxis_index=1,
        label_opts=opts.LabelOpts(is_show=False, position='left'),
    )
)

bar.overlap(line)
grid = Grid(init_opts=opts.InitOpts(theme=ThemeType.VINTAGE))
grid.add(bar, opts.GridOpts(pos_left="10%", pos_right="10%", pos_bottom="25%"), is_control_axis_index=True)
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="72c98fa86ea04888a4329ac28881087a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_72c98fa86ea04888a4329ac28881087a = echarts.init(
#                     document.getElementById('72c98fa86ea04888a4329ac28881087a'), 'vintage', {renderer: 'canvas'});
#                 var option_72c98fa86ea04888a4329ac28881087a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u9500\u552e\u989d",
#             "yAxisIndex": 0,
#             "data": [
#                 677577.0,
#                 405581.9,
#                 325316.6,
#                 277307.9,
#                 262420.0,
#                 214165.8,
#                 162156.9,
#                 154459.5,
#                 84627.0,
#                 67854.6,
#                 63493.8,
#                 59540.3,
#                 45828.3,
#                 44006.4,
#                 41284.5,
#                 39480.0,
#                 37018.2,
#                 33552.0,
#                 29143.8,
#                 26504.4,
#                 22667.4,
#                 20780.1,
#                 19790.1,
#                 15651.3,
#                 15166.2,
#                 12943.8,
#                 9190.8
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "left",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u7d2f\u8ba1\u9500\u552e\u989d\u5360\u6bd4",
#             "connectNulls": false,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "AmazerBath",
#                     0.21
#                 ],
#                 [
#                     "mDesign",
#                     0.34
#                 ],
#                 [
#                     "Stall",
#                     0.44
#                 ],
#                 [
#                     "Madison Park",
#                     0.53
#                 ],
#                 [
#                     "Amazon Basics",
#                     0.62
#                 ],
#                 [
#                     "Lush Decor",
#                     0.68
#                 ],
#                 [
#                     "YoKII",
#                     0.73
#                 ],
#                 [
#                     "Barossa Design",
#                     0.78
#                 ],
#                 [
#                     "Volens",
#                     0.8
#                 ],
#                 [
#                     "ARICHOMY",
#                     0.82
#                 ],
#                 [
#                     "Reisen",
#                     0.84
#                 ],
#                 [
#                     "Biscaynebay",
#                     0.86
#                 ],
#                 [
#                     "N&Y HOME",
#                     0.88
#                 ],
#                 [
#                     "Comfort Spaces",
#                     0.89
#                 ],
#                 [
#                     "Mrs Awesome",
#                     0.91
#                 ],
#                 [
#                     "DOSLY ID\u00c9ES",
#                     0.92
#                 ],
#                 [
#                     "Kikcoin",
#                     0.93
#                 ],
#                 [
#                     "HALL & PERRY",
#                     0.94
#                 ],
#                 [
#                     "Felisa",
#                     0.95
#                 ],
#                 [
#                     "UFRIDAY",
#                     0.96
#                 ],
#                 [
#                     "CAROMIO",
#                     0.96
#                 ],
#                 [
#                     "Eforcurtain",
#                     0.97
#                 ],
#                 [
#                     "WestWeir",
#                     0.97
#                 ],
#                 [
#                     "YOSTEV",
#                     0.98
#                 ],
#                 [
#                     "Italian Collection",
#                     0.99
#                 ],
#                 [
#                     "Central Park",
#                     1.0
#                 ],
#                 [
#                     "Carnation",
#                     1.0
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "left",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9500\u552e\u989d",
#                 "\u7d2f\u8ba1\u9500\u552e\u989d\u5360\u6bd4"
#             ],
#             "selected": {
#                 "\u9500\u552e\u989d": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": true,
#                 "inside": false
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -90,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "AmazerBath",
#                 "mDesign",
#                 "Stall",
#                 "Madison Park",
#                 "Amazon Basics",
#                 "Lush Decor",
#                 "YoKII",
#                 "Barossa Design",
#                 "Volens",
#                 "ARICHOMY",
#                 "Reisen",
#                 "Biscaynebay",
#                 "N&Y HOME",
#                 "Comfort Spaces",
#                 "Mrs Awesome",
#                 "DOSLY ID\u00c9ES",
#                 "Kikcoin",
#                 "HALL & PERRY",
#                 "Felisa",
#                 "UFRIDAY",
#                 "CAROMIO",
#                 "Eforcurtain",
#                 "WestWeir",
#                 "YOSTEV",
#                 "Italian Collection",
#                 "Central Park",
#                 "Carnation"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end

# %% [markdown]
# &emsp;&emsp;同样可以看出：
# 1. AmazerrBath 品牌的浴帘销售额最高且明显高于其他品牌;
# 2. 从累计销量占比来看，前四个品牌的浴帘销售额占比超过50%。

# %%
sale_data.corr()
# Out:
#           销售额        销量
# 销售额  1.000000  0.970239
# 销量   0.970239  1.000000

# %% [markdown]
# &emsp;&emsp;销售额与销量的相关性也符合规律。

# %% [markdown]
# # 销售周期

# %% [markdown]
# &emsp;&emsp;先计算上架天数：

# %%
data['上架天数'] = (pd.Timestamp('2021-1-22') - data['上架时间'])/np.timedelta64(1, 'D')

# %% [markdown]
# &emsp;&emsp;再对上架天数进行分段统计：

# %%
data['上架天数'].describe()
# Out:
# count      46.000000
# mean      692.673913
# std       701.470077
# min        15.000000
# 25%       303.250000
# 50%       524.000000
# 75%       719.250000
# max      3574.000000
# Name: 上架天数, dtype: float64

# %%
shelves_data = pd.cut(
    data['上架天数'], [
        0,
        100,
        300,
        600,
        1000,
        100000
    ],
    labels=['100天以下', '100~300天', '300~600天', '600~1000天', '1000天以上']).value_counts()

# %%
histogram = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.VINTAGE))
    .add_xaxis(shelves_data.index.tolist())
    .add_yaxis("", shelves_data.values.tolist(), category_gap=0)
    .set_global_opts(title_opts=opts.TitleOpts(title="上架天数分布", pos_left='center'))
    .render_notebook()
)

histogram
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="1cbd38db93dc4049aaacfe88ae9c6b86" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_1cbd38db93dc4049aaacfe88ae9c6b86 = echarts.init(
#                     document.getElementById('1cbd38db93dc4049aaacfe88ae9c6b86'), 'vintage', {renderer: 'canvas'});
#                 var option_1cbd38db93dc4049aaacfe88ae9c6b86 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 16,
#                 11,
#                 10,
#                 7,
#                 2
#             ],
#             "barCategoryGap": 0,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "300~600\u5929",
#                 "600~1000\u5929",
#                 "100~300\u5929",
#                 "1000\u5929\u4ee5\u4e0a",
#                 "100\u5929\u4ee5\u4e0b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u4e0a\u67b6\u5929\u6570\u5206\u5e03",
#             "left": "center",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_1cbd38db93dc4049aaacfe88ae9c6b86.setOption(option_1cbd38db93dc4049aaacfe88ae9c6b86);
#         });
#     </script>

# %% [markdown]
# &emsp;&emsp;可以看出：大部分商品的上架天数均大于300天，表明各商品销售时间均比较长，商品样式更换速度慢。

# %%
data['上架月份'] = data['上架时间'].map(lambda x: x.month)

# %%
shelves_month_data = data.groupby('上架月份')['上架时间'].count()

# %%
bar = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.VINTAGE))
    .add_xaxis(shelves_month_data.index.tolist())
    .add_yaxis("", shelves_month_data.tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="上架月份分布", pos_left='center'))
    .render_notebook()
)

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="6c08c159af1545ae95d5742ef0aabb07" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_6c08c159af1545ae95d5742ef0aabb07 = echarts.init(
#                     document.getElementById('6c08c159af1545ae95d5742ef0aabb07'), 'vintage', {renderer: 'canvas'});
#                 var option_6c08c159af1545ae95d5742ef0aabb07 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 4,
#                 4,
#                 4,
#                 7,
#                 4,
#                 4,
#                 7,
#                 5,
#                 2,
#                 3,
#                 2
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 1,
#                 2,
#                 4,
#                 5,
#                 6,
#                 7,
#                 8,
#                 9,
#                 10,
#                 11,
#                 12
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u4e0a\u67b6\u6708\u4efd\u5206\u5e03",
#             "left": "center",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_6c08c159af1545ae95d5742ef0aabb07.setOption(option_6c08c159af1545ae95d5742ef0aabb07);
#         });
#     </script>

# %% [markdown]
# &emsp;&emsp;可以看出：年末商品上架数量比较少，多集中在5月、8月上架新商品。

# %% [markdown]
# # 价格分布

# %%
data['价格'].describe()
# Out:
# count    46.000000
# mean     19.935870
# std       6.323935
# min       8.280000
# 25%      14.990000
# 50%      19.990000
# 75%      23.865000
# max      39.990000
# Name: 价格, dtype: float64

# %%
price_data = pd.cut(
    data['价格'], [
        0,
        10,
        15,
        20,
        25,
        30,
        35, 
        40
    ],
    labels=['0~10', '10~15', '15~20', '20~25', '25~30', '30~35', '35~40']).value_counts()

# %%
bar = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.VINTAGE))
    .add_xaxis(price_data.index.tolist())
    .add_yaxis("", price_data.tolist(), category_gap=0)
    .set_global_opts(
        title_opts=opts.TitleOpts(title="浴帘价格分布", pos_left='center'),
        legend_opts=opts.LegendOpts(is_show=False),
        xaxis_opts=opts.AxisOpts(name="单位：美元")
    )
    .render_notebook()
)

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="e68a0114cecd467f8d38866eba362670" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_e68a0114cecd467f8d38866eba362670 = echarts.init(
#                     document.getElementById('e68a0114cecd467f8d38866eba362670'), 'vintage', {renderer: 'canvas'});
#                 var option_e68a0114cecd467f8d38866eba362670 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 14,
#                 13,
#                 12,
#                 3,
#                 2,
#                 1,
#                 1
#             ],
#             "barCategoryGap": 0,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "name": "\u5355\u4f4d\uff1a\u7f8e\u5143",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "20~25",
#                 "15~20",
#                 "10~15",
#                 "25~30",
#                 "30~35",
#                 "35~40",
#                 "0~10"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6d74\u5e18\u4ef7\u683c\u5206\u5e03",
#             "left": "center",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_e68a0114cecd467f8d38866eba362670.setOption(option_e68a0114cecd467f8d38866eba362670);
#         });
#     </script>

# %% [markdown]
# &emsp;&emsp;可以看出：浴帘价格集中在 10\~25 美元，其中 20\~25 美元区间内的商品数量最多。

# %% [markdown]
# # 品牌价格区间与销量

# %%
data['价格区间'] = pd.cut(
    data['价格'], [
        0,
        10,
        15,
        20,
        25,
        30,
        35, 
        40
    ],
    labels=['0~10', '10~15', '15~20', '20~25', '25~30', '30~35', '35~40'])

# %%
price_sale_data = data.pivot_table(
    index = '商标',
    columns = '价格区间',
    values = '销量',
    aggfunc=np.sum
)

# %%
value = [[j, i, price_sale_data.iloc[i, j]]
         for i in range(len(price_sale_data.index))
         for j in range(len(price_sale_data.columns))]

# %%
heatmap = (
    HeatMap()
    .add_xaxis(price_sale_data.columns.tolist())
    .add_yaxis(
        "", 
        price_sale_data.index.tolist(), 
        value=value, 
        label_opts=opts.LabelOpts(is_show=True, position="inside")
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="浴帘品牌价格区间与销量", pos_left = 'center'),
        xaxis_opts=opts.AxisOpts(name="单位：美元", axislabel_opts={"interval":"-10"}),
        visualmap_opts=opts.VisualMapOpts(min_=500, max_=45000)
    )
)

grid = Grid(init_opts=opts.InitOpts(theme=ThemeType.VINTAGE))
grid.add(heatmap, opts.GridOpts(pos_left='20%', pos_top='5%', pos_bottom='5%'), is_control_axis_index=True)
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="d2e12713c5794692ae8c31d513ecb0aa" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_d2e12713c5794692ae8c31d513ecb0aa = echarts.init(
#                     document.getElementById('d2e12713c5794692ae8c31d513ecb0aa'), 'vintage', {renderer: 'canvas'});
#                 var option_d2e12713c5794692ae8c31d513ecb0aa = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [],
#     "series": [
#         {
#             "type": "heatmap",
#             "data": [
#                 [
#                     0,
#                     0,
#                     null
#                 ],
#                 [
#                     1,
#                     0,
#                     null
#                 ],
#                 [
#                     2,
#                     0,
#                     4140.0
#                 ],
#                 [
#                     3,
#                     0,
#                     null
#                 ],
#                 [
#                     4,
#                     0,
#                     null
#                 ],
#                 [
#                     5,
#                     0,
#                     null
#                 ],
#                 [
#                     6,
#                     0,
#                     null
#                 ],
#                 [
#                     0,
#                     1,
#                     null
#                 ],
#                 [
#                     1,
#                     1,
#                     43440.0
#                 ],
#                 [
#                     2,
#                     1,
#                     null
#                 ],
#                 [
#                     3,
#                     1,
#                     4860.0
#                 ],
#                 [
#                     4,
#                     1,
#                     null
#                 ],
#                 [
#                     5,
#                     1,
#                     null
#                 ],
#                 [
#                     6,
#                     1,
#                     null
#                 ],
#                 [
#                     0,
#                     2,
#                     null
#                 ],
#                 [
#                     1,
#                     2,
#                     null
#                 ],
#                 [
#                     2,
#                     2,
#                     null
#                 ],
#                 [
#                     3,
#                     2,
#                     10501.0
#                 ],
#                 [
#                     4,
#                     2,
#                     null
#                 ],
#                 [
#                     5,
#                     2,
#                     null
#                 ],
#                 [
#                     6,
#                     2,
#                     null
#                 ],
#                 [
#                     0,
#                     3,
#                     null
#                 ],
#                 [
#                     1,
#                     3,
#                     1440.0
#                 ],
#                 [
#                     2,
#                     3,
#                     null
#                 ],
#                 [
#                     3,
#                     3,
#                     5610.0
#                 ],
#                 [
#                     4,
#                     3,
#                     null
#                 ],
#                 [
#                     5,
#                     3,
#                     null
#                 ],
#                 [
#                     6,
#                     3,
#                     null
#                 ],
#                 [
#                     0,
#                     4,
#                     null
#                 ],
#                 [
#                     1,
#                     4,
#                     3972.0
#                 ],
#                 [
#                     2,
#                     4,
#                     null
#                 ],
#                 [
#                     3,
#                     4,
#                     null
#                 ],
#                 [
#                     4,
#                     4,
#                     null
#                 ],
#                 [
#                     5,
#                     4,
#                     null
#                 ],
#                 [
#                     6,
#                     4,
#                     null
#                 ],
#                 [
#                     0,
#                     5,
#                     null
#                 ],
#                 [
#                     1,
#                     5,
#                     null
#                 ],
#                 [
#                     2,
#                     5,
#                     1260.0
#                 ],
#                 [
#                     3,
#                     5,
#                     null
#                 ],
#                 [
#                     4,
#                     5,
#                     null
#                 ],
#                 [
#                     5,
#                     5,
#                     null
#                 ],
#                 [
#                     6,
#                     5,
#                     null
#                 ],
#                 [
#                     0,
#                     6,
#                     1110.0
#                 ],
#                 [
#                     1,
#                     6,
#                     null
#                 ],
#                 [
#                     2,
#                     6,
#                     null
#                 ],
#                 [
#                     3,
#                     6,
#                     null
#                 ],
#                 [
#                     4,
#                     6,
#                     null
#                 ],
#                 [
#                     5,
#                     6,
#                     null
#                 ],
#                 [
#                     6,
#                     6,
#                     null
#                 ],
#                 [
#                     0,
#                     7,
#                     null
#                 ],
#                 [
#                     1,
#                     7,
#                     null
#                 ],
#                 [
#                     2,
#                     7,
#                     810.0
#                 ],
#                 [
#                     3,
#                     7,
#                     null
#                 ],
#                 [
#                     4,
#                     7,
#                     null
#                 ],
#                 [
#                     5,
#                     7,
#                     null
#                 ],
#                 [
#                     6,
#                     7,
#                     null
#                 ],
#                 [
#                     0,
#                     8,
#                     null
#                 ],
#                 [
#                     1,
#                     8,
#                     null
#                 ],
#                 [
#                     2,
#                     8,
#                     null
#                 ],
#                 [
#                     3,
#                     8,
#                     1920.0
#                 ],
#                 [
#                     4,
#                     8,
#                     null
#                 ],
#                 [
#                     5,
#                     8,
#                     null
#                 ],
#                 [
#                     6,
#                     8,
#                     null
#                 ],
#                 [
#                     0,
#                     9,
#                     null
#                 ],
#                 [
#                     1,
#                     9,
#                     n

# %% [markdown]
# &emsp;&emsp;结论：10~15美元的浴帘销量最高，为 68,130，其中 AmazerBath 品牌的浴帘销量最高，占比约为64%。

# %%
price_sale_data.sum()
(price_sale_data.sum())/(price_sale_data.sum().sum())
price_sale_data.loc['AmazerBath', '10~15']/price_sale_data.loc[:, '10~15'].sum()
# Out:
# 价格区间
# 0~10      1110.0
# 10~15    68130.0
# 15~20    55127.0
# 20~25    38803.0
# 25~30     6060.0
# 30~35     4500.0
# 35~40     1410.0
# dtype: float64
# 价格区间
# 0~10     0.006338
# 10~15    0.389003
# 15~20    0.314760
# 20~25    0.221554
# 25~30    0.034601
# 30~35    0.025694
# 35~40    0.008051
# dtype: float64
# 0.637604579480405

# %% [markdown]
# # 品牌的评分

# %%
bar = (
    Bar()
    .add_xaxis(sale_data.index.tolist())
    .add_yaxis(
        "", 
        sale_data['评分'].tolist(),
        markline_opts=opts.MarkLineOpts(
               data=[opts.MarkLineItem(type_='average', name='平均值')]
           )
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="浴帘品牌评分", pos_left='center'),
        yaxis_opts=opts.AxisOpts(min_ = 4),
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-90))
    )
)

grid = Grid(init_opts=opts.InitOpts(theme=ThemeType.VINTAGE))
grid.add(bar, opts.GridOpts(pos_bottom="25%"), is_control_axis_index=True)
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="ebbe51e7437d41ebba4fe2315ad1e0fe" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_ebbe51e7437d41ebba4fe2315ad1e0fe = echarts.init(
#                     document.getElementById('ebbe51e7437d41ebba4fe2315ad1e0fe'), 'vintage', {renderer: 'canvas'});
#                 var option_ebbe51e7437d41ebba4fe2315ad1e0fe = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 4.7,
#                 4.7,
#                 4.6,
#                 4.7,
#                 4.7,
#                 4.7,
#                 4.3,
#                 4.8,
#                 4.6,
#                 4.7,
#                 4.6,
#                 4.4,
#                 4.5,
#                 4.3,
#                 4.5,
#                 4.7,
#                 4.6,
#                 4.7,
#                 4.1,
#                 4.7,
#                 4.8,
#                 4.5,
#                 4.8,
#                 4.7,
#                 4.6,
#                 4.5,
#                 4.5
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -90,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "ARICHOMY",
#                 "AmazerBath",
#                 "Amazon Basics",
#                 "Barossa Design",
#                 "Biscaynebay",
#                 "CAROMIO",
#                 "Carnation",
#                 "Central Park",
#                 "Comfort Spaces",
#                 "DOSLY ID\u00c9ES",
#                 "Eforcurtain",
#                 "Felisa",
#                 "HALL & PERRY",
#                 "Italian Collection",
#                 "Kikcoin",
#                 "Lush Decor",
#                 "Madison Park",
#                 "Mrs Awesome",
#                 "N&Y HOME",
#                 "Reisen",
#                 "Stall",
#                 "UFRIDAY",
#                 "Volens",
#                 "WestWeir",
#                 "YOSTEV",
#                 "YoKII",
#                 "mDesign"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "min": 4,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6d74\u5e18\u54c1\u724c\u8bc4\u5206",
#             "left": "center",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "grid": [
#         {
#             "bottom": "25%",
#             "containLabel": false
#         }
#     ]
# };
#                 chart_ebbe51e7437d41ebba4fe2315ad1e0fe.setOption(option_ebbe51e7437d41ebba4fe2315ad1e0fe);
#         });
#     </script>

# %% [markdown]
# &emsp;&emsp;结论：浴帘商品的平均评分为4.59，有 18 个商品的评分超过平均评分（总数为27个）。

# %%
sale_data[['销量', '评分']].corr()
# Out:
#           销量        评分
# 销量  1.000000  0.168746
# 评分  0.168746  1.000000

# %% [markdown]
# &emsp;&emsp;从销量与评分的相关系数来看，评分对销量的影响相对比较小。

# %% [markdown]
# # 商品的评价数量

# %%
data['评价数量'].describe()
# Out:
# count       46.000000
# mean      3086.239130
# std       6526.992413
# min         37.000000
# 25%        934.000000
# 50%       1881.000000
# 75%       2913.750000
# max      44610.000000
# Name: 评价数量, dtype: float64

# %%
score_num_data = pd.cut(
    data['评价数量'], [
        0,
        100,
        500,
        1000,
        2000,
        3000,
        1000000
    ],
    labels=['0~100', '100~500', '500~1000', '1000~2000', '2000~3000', '3000以上']).value_counts()

# %%
pie = (
    Pie(init_opts=opts.InitOpts(theme=ThemeType.VINTAGE))
    .add("", [list(i) for i in zip(score_num_data.index.tolist(), score_num_data.values.tolist())])
    .set_global_opts(
        title_opts=opts.TitleOpts(title="浴帘评价数分布", pos_left="center"),
        legend_opts=opts.LegendOpts(is_show=False)
    )
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {d}%"))
    .render_notebook()
)
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="99cd4db752f248659f38a01046e60680" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_99cd4db752f248659f38a01046e60680 = echarts.init(
#                     document.getElementById('99cd4db752f248659f38a01046e60680'), 'vintage', {renderer: 'canvas'});
#                 var option_99cd4db752f248659f38a01046e60680 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "1000~2000",
#                     "value": 13
#                 },
#                 {
#                     "name": "3000\u4ee5\u4e0a",
#                     "value": 12
#                 },
#                 {
#                     "name": "2000~3000",
#                     "value": 9
#                 },
#                 {
#                     "name": "500~1000",
#                     "value": 5
#                 },
#                 {
#                     "name": "100~500",
#                     "value": 4
#                 },
#                 {
#                     "name": "0~100",
#                     "value": 3
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {d}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "1000~2000",
#                 "3000\u4ee5\u4e0a",
#                 "2000~3000",
#                 "500~1000",
#                 "100~500",
#                 "0~100"
#             ],
#             "selected": {},
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u6d74\u5e18\u8bc4\u4ef7\u6570\u5206\u5e03",
#             "left": "center",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_99cd4db752f248659f38a01046e60680.setOption(option_99cd4db752f248659f38a01046e60680);
#         });
#     </script>

# %% [markdown]
# &emsp;&emsp;结论：浴帘商品的评论数普遍偏多，1000以下的评论数仅占 26.09%。
